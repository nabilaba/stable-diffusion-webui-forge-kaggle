# %%
# !rm -rf ./*
# !rm -rf .[^.]*
# !git clone https://github.com/nabilaba/stable-diffusion-webui-forge-kaggle.git .
# !python script.py token="..." extension="https://github.com/nabilaba/file-deleter-stable-diffusion-webui.git" stable-diffusion="..."
