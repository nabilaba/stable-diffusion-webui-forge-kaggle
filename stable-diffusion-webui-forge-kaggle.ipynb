# %%
import os, threading, time

TOKEN = "..."

print("📦 Install Zrok")
# !curl -sSL https://get.openziti.io/install.bash | sudo bash -s zrok

print("🔐 Enabling Zrok (headless)")
# !zrok enable --headless {TOKEN}

print("📁 Starting SD WebUI Forge")
# %cd /kaggle/working/
BASE_FOLDER = "nabil"

# !git clone https://github.com/lllyasviel/stable-diffusion-webui-forge.git {BASE_FOLDER}
# %cd {BASE_FOLDER}

# ControlNet 1.1
# Tile
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/67566?type=Model&format=SafeTensor"
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/67566?type=Config&format=Other"

# Depth
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44736?type=Model&format=SafeTensor"
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44736?type=Config&format=Other"

# OpenPose
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44811?type=Model&format=SafeTensor&size=pruned&fp=fp16"
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44811?type=Config&format=Other"

# Canny
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44716?type=Model&format=SafeTensor&size=pruned&fp=fp16"
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44716?type=Config&format=Other"

# Scribble
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44787?type=Model&format=SafeTensor&size=pruned&fp=fp16"
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44787?type=Config&format=Other"

# Lineart
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44877?type=Model&format=SafeTensor&size=pruned&fp=fp16"
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/44877?type=Config&format=Other"

# ControlNet XL
# Canny Anime
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/155263?type=Model&format=SafeTensor&size=full&fp=fp32&token=a17a18304886a8f0cd35759b15769600"

# Depth Anime
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/155265?type=Model&format=SafeTensor&size=full&fp=fp32&token=a17a18304886a8f0cd35759b15769600"

# OpenPose Anime v2
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/155270?type=Model&format=SafeTensor&size=full&fp=fp32&token=a17a18304886a8f0cd35759b15769600"

# Replicate Anime v2
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/164965?type=Model&format=SafeTensor&size=full&fp=fp32&token=a17a18304886a8f0cd35759b15769600"

# Scribble
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/155273?type=Model&format=SafeTensor&size=full&fp=fp32&token=a17a18304886a8f0cd35759b15769600"

# Lineart
# !wget --content-disposition -P models/ControlNet "https://civitai.com/api/download/models/267516?type=Model&format=SafeTensor&size=full&fp=fp16&token=a17a18304886a8f0cd35759b15769600"

# Lora
# !wget --content-disposition -P models/Lora "https://civitai.com/api/download/models/135867?type=Model&format=SafeTensor"

# Embeddings
# !wget --content-disposition -P embeddings "https://civitai.com/api/download/models/77169?type=Model&format=PickleTensor"

# ControlNet Support
# !wget --content-disposition -P models/ControlNetPreprocessor/midas/ "https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/dpt_hybrid-midas-501f0c75.pt"

# OpenPose Preprocessor
# !wget --content-disposition -P models/ControlNetPreprocessor/openpose/ "https://huggingface.co/yzd-v/DWPose/resolve/main/yolox_l.onnx"
# !wget --content-disposition -P models/ControlNetPreprocessor/openpose/ "https://huggingface.co/yzd-v/DWPose/resolve/main/dw-ll_coco_512.onnx"

def run_webui():
    while True:
        print("🚀 Launching Stable Diffusion WebUI...")
        exit_code = os.system("python3 launch.py --listen --port 7860 --xformers --enable-insecure-extension-access")
        print(f"❌ WebUI exited with code {exit_code}. Restarting...")

threading.Thread(target=run_webui).start()

print("⏳ Waiting for WebUI")
time.sleep(20)

print("🌐 Creating Zrok share (headless)")
# !zrok share public --headless "http://localhost:7860"
